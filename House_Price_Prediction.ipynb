# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Data Cleaning

# %%
data1=pd.read_csv('/content/Housing_with_Locations.csv')
data1
# Out:
#         Price  Area in sqft.  Bedrooms  Bathrooms  Stories Mainroad  \
# 0     1750000           3620         2          1        1      yes
# 1     1750000           2910         3          1        1      yes
# 2     1750000           3850         3          1        2      yes
# 3     1767150           2400         3          1        1      yes
# 4     1820000           3000         2          1        1      yes
# ..        ...            ...       ...        ...      ...      ...
# 540  11410000           7420         4          1        2      yes
# 541  12215000           7500         4          2        2      yes
# 542  12250000           8960         4          4        4       no
# 543  12250000           9960         3          2        2      yes
# 544  13300000           7420         4          2        3      yes
#
#     Guestrooms Basement Air Conditioning  Parking Area Preferred Area  \
# 0           no       no              yes             2            yes
# 1           no       no              yes             3             no
# 2           no       no              yes             2            yes
# 3           no       no               no             0             no
# 4          yes       no              yes             1            yes
# ..         ...      ...              ...           ...            ...
# 540         no      yes               no             1             no
# 541         no      yes               no             0             no
# 542         no      yes               no             0             no
# 543         no      yes               no             0             no
# 544         no      yes               no             2             no
#
#     Furnishing Status               Location
# 0           furnished  Whitefield, Bangalore
# 1           furnished       Sector 62, Noida
# 2      semi-furnished  Gachibowli, Hyderabad
# 3         unfurnished  Gachibowli, Hyderabad
# 4         unfurnished         Bandra, Mumbai
# ..                ...                    ...
# 540         furnished     Sector 49, Gurgaon
# 541       unfurnished  Whitefield, Bangalore
# 542    semi-furnished     Vashi, Navi Mumbai
# 543       unfurnished        Andheri, Mumbai
# 544       unfurnished           Saket, Delhi
#
# [545 rows x 13 columns]

# %%
data1.drop(columns=['Stories','Mainroad','Preferred Area'],axis=1,inplace=True)

# %%
data1
# Out:
#         Price  Area in sqft.  Bedrooms  Bathrooms Guestrooms Basement  \
# 0     1750000           3620         2          1         no       no
# 1     1750000           2910         3          1         no       no
# 2     1750000           3850         3          1         no       no
# 3     1767150           2400         3          1         no       no
# 4     1820000           3000         2          1        yes       no
# ..        ...            ...       ...        ...        ...      ...
# 540  11410000           7420         4          1         no      yes
# 541  12215000           7500         4          2         no      yes
# 542  12250000           8960         4          4         no      yes
# 543  12250000           9960         3          2         no      yes
# 544  13300000           7420         4          2         no      yes
#
#     Air Conditioning  Parking Area Furnishing Status               Location
# 0                yes             2         furnished  Whitefield, Bangalore
# 1                yes             3         furnished       Sector 62, Noida
# 2                yes             2    semi-furnished  Gachibowli, Hyderabad
# 3                 no             0       unfurnished  Gachibowli, Hyderabad
# 4                yes             1       unfurnished         Bandra, Mumbai
# ..               ...           ...               ...                    ...
# 540               no             1         furnished     Sector 49, Gurgaon
# 541               no             0       unfurnished  Whitefield, Bangalore
# 542               no             0    semi-furnished     Vashi, Navi Mumbai
# 543               no             0       unfurnished        Andheri, Mumbai
# 544               no             2       unfurnished           Saket, Delhi
#
# [545 rows x 10 columns]

# %%
data1['Guestrooms']=data1['Guestrooms'].apply(lambda x: 1 if x == 'yes' else 0)
data1['Air Conditioning']=data1['Air Conditioning'].apply(lambda x: 1 if x == 'yes' else 0)
data1['Basement']=data1['Basement'].apply(lambda x: 1 if x == 'yes' else 0)
data1['Furnishing Status']=data1['Furnishing Status'].apply(lambda x: 2 if x == 'furnished' else 1 if x == 'semi-furnished' else 0)

# %%
data1
# Out:
#         Price  Area in sqft.  Bedrooms  Bathrooms  Guestrooms  Basement  \
# 0     1750000           3620         2          1           0         0
# 1     1750000           2910         3          1           0         0
# 2     1750000           3850         3          1           0         0
# 3     1767150           2400         3          1           0         0
# 4     1820000           3000         2          1           1         0
# ..        ...            ...       ...        ...         ...       ...
# 540  11410000           7420         4          1           0         1
# 541  12215000           7500         4          2           0         1
# 542  12250000           8960         4          4           0         1
# 543  12250000           9960         3          2           0         1
# 544  13300000           7420         4          2           0         1
#
#      Air Conditioning  Parking Area  Furnishing Status               Location
# 0                   1             2                  2  Whitefield, Bangalore
# 1                   1             3                  2       Sector 62, Noida
# 2                   1             2                  1  Gachibowli, Hyderabad
# 3                   0             0                  0  Gachibowli, Hyderabad
# 4                   1             1                  0         Bandra, Mumbai
# ..                ...           ...                ...                    ...
# 540                 0             1                  2     Sector 49, Gurgaon
# 541                 0             0                  0  Whitefield, Bangalore
# 542                 0             0                  1     Vashi, Navi Mumbai
# 543                 0             0                  0        Andheri, Mumbai
# 544                 0             2                  0           Saket, Delhi
#
# [545 rows x 10 columns]

# %%
data1.isna().sum()
# Out:
# Price                0
# Area in sqft.        0
# Bedrooms             0
# Bathrooms            0
# Guestrooms           0
# Basement             0
# Air Conditioning     0
# Parking Area         0
# Furnishing Status    0
# Location             0
# dtype: int64

# %% [markdown]
# Correlation and Covariance

# %%
data1[['Area in sqft.','Price']].corr()
# Out:
#                Area in sqft.     Price
# Area in sqft.       1.000000  0.535997
# Price               0.535997  1.000000

# %%
data1[['Area in sqft.','Price']].cov()
# Out:
#                Area in sqft.         Price
# Area in sqft.   4.709512e+06  2.175676e+09
# Price           2.175676e+09  3.498544e+12

# %%
object_columns=data1.select_dtypes(include=['object']).columns
object_columns
# Out:
# Index(['Location'], dtype='object')

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder

# %%
col_transfor=make_column_transformer(
    (OneHotEncoder(sparse_output=False),['Location']),
    remainder='passthrough'
)

# %%
Y=data1['Price']
X=data1.drop('Price',axis=1)

# %%
Scaler=StandardScaler()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train.shape,Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((436, 9), (436,), (109, 9), (109,))

# %%
rfr=RandomForestRegressor()

# %%
predicts=make_pipeline(col_transfor,Scaler,rfr)

# %%
predicts.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['Location'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('randomforestregressor', RandomForestRegressor())])

# %%
predicts.score(X_test,Y_test)
# Out:
# 0.7576133999467122

# %%
mean_squared_error(Y_test,predicts.predict(X_test))
# Out:
# 778921333623.5215

# %%
data1
# Out:
#         Price  Area in sqft.  Bedrooms  Bathrooms  Guestrooms  Basement  \
# 0     1750000           3620         2          1           0         0
# 1     1750000           2910         3          1           0         0
# 2     1750000           3850         3          1           0         0
# 3     1767150           2400         3          1           0         0
# 4     1820000           3000         2          1           1         0
# ..        ...            ...       ...        ...         ...       ...
# 540  11410000           7420         4          1           0         1
# 541  12215000           7500         4          2           0         1
# 542  12250000           8960         4          4           0         1
# 543  12250000           9960         3          2           0         1
# 544  13300000           7420         4          2           0         1
#
#      Air Conditioning  Parking Area  Furnishing Status               Location
# 0                   1             2                  2  Whitefield, Bangalore
# 1                   1             3                  2       Sector 62, Noida
# 2                   1             2                  1  Gachibowli, Hyderabad
# 3                   0             0                  0  Gachibowli, Hyderabad
# 4                   1             1                  0         Bandra, Mumbai
# ..                ...           ...                ...                    ...
# 540                 0             1                  2     Sector 49, Gurgaon
# 541                 0             0                  0  Whitefield, Bangalore
# 542                 0             0                  1     Vashi, Navi Mumbai
# 543                 0             0                  0        Andheri, Mumbai
# 544                 0             2                  0           Saket, Delhi
#
# [545 rows x 10 columns]

# %%
input=pd.DataFrame([[12250000,9960,4,4,0,0,0,0,1,'Andheri, Mumbai']],columns=['Price','Area in sqft.','Bedrooms','Bathrooms','Guestrooms','Basement','Air Conditioning','Parking Area','Furnishing Status','Location'])

# %%
predicts.predict(input)
# Out:
# array([4524730.])

# %%
import pickle as pk

# %%
pk.dump(predicts,open('House_price_prediction_model.pkl','wb'))

# %%
data1.to_csv('Housing_Dataset.csv',index=False)
